# %% [markdown]
# # SageMaker Analysis Report

# %% [markdown]
# We report the following SageMaker analysis.

# %% [markdown]
# ## Explanations for all labels

# %% [markdown]
# The Model has `2` input features and `32` output labels. We computed KernelShap on the dataset and display the `10` features with the greatest feature attribution summed up over all the labels.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for ""Any discussion related in any way to market manipulation is strictly prohibited, as is advising others on whether to buy, sell, or hold.""

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Account number visible. Please remove from content before reposting."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Bullying a member or moderator."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Bypassing the chat filters is not allowed."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "CMEG complaint"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Caps for tickers only."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Discord is not an allowed word in the room. Please don't bypass the filter "

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "English only please!"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "False information or no source."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "False information."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "False or misleading information, or no source."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Inappropriate comment."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Language"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Might be searching for offline contact"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "No reference to 3rd party contact"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Not sure what this is"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Off-topic"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Personal or sensitive information not allowed in chat."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Perv is an inappropriate term please refrain from these kinds of discussions here"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Please provide more information when making comments like these. For example "AFRM is being shorted every candle, so I think it's manipulated" "

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Politics not allowed outside of references to the market."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Reviewed by admin internally; not necessary to post to public chat."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Support Room would be more appropriate for this inquiry."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "Third-party links / content not allowed."

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "comments about market manipulation not allowed even if joking"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "gray area"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "language please"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "no advice"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "outside link"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "password"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "possible password"

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>

# %% [markdown]
# ## Explanations for "talking about drugs "

# %% [markdown]
# The Model has `2` input features. We computed KernelShap on the dataset         `dataset` and display the `10` features with the greatest feature attribution.
# <br><img src='data:image/png;base64,...'><br>
